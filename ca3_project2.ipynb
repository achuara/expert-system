# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skfuzzy as fuzzy
from skfuzzy import control as ctrl

# %%
# INPUTS >>>>>
#-----------------------------------------------------------------
PHYSICS = ctrl.Antecedent(np.arange(0,101,1) , 'PHYSICS')
CHEMISTRY = ctrl.Antecedent(np.arange(0,101,1) , 'CHEMISTRY')
MATHS = ctrl.Antecedent(np.arange(0,101,1) , 'MATHS')
ENGLISH = ctrl.Antecedent(np.arange(0,101,1) , 'ENGLISH')
BIOLOGY = ctrl.Antecedent(np.arange(0,101,1) , 'BIOLOGY')
Computer_Science = ctrl.Antecedent(np.arange(0,101,1) , 'Computer_Science')
physical_education = ctrl.Antecedent(np.arange(0,101,1) , 'physical_education')
FINANCE = ctrl.Antecedent(np.arange(0,101,1) , 'FINANCE')
ACCOUNTANCY = ctrl.Antecedent(np.arange(0,101,1) , 'ACCOUNTANCY')
BUSINESS_STUDIES = ctrl.Antecedent(np.arange(0,101,1) , 'BUSINESS_STUDIES')
ECONOMICS = ctrl.Antecedent(np.arange(0,101,1) , 'ECONOMICS')
HISTORY = ctrl.Antecedent(np.arange(0,101,1) , 'HISTORY')
GEOGRAPHY = ctrl.Antecedent(np.arange(0,101,1) , 'GEOGRAPHY')
SOCIOLOGY = ctrl.Antecedent(np.arange(0,101,1) , 'SOCIOLOGY')

# OUTPUTS >>>>>>
#-----------------------------------------------------------------------------------
ENGINEERING = ctrl.Consequent(np.arange(85,100,1) , 'ENGINEERING')
MBBS = ctrl.Consequent(np.arange(88,100,1) , 'MBBS')
BAMS = ctrl.Consequent(np.arange(80,90,1) , 'BAMS')
BHMS = ctrl.Consequent(np.arange(74,83,1) , 'BHMS')
BDS = ctrl.Consequent(np.arange(76,85,1) , 'BDS')
BACHELOR_OF_SCIENCE = ctrl.Consequent(np.arange(78,86,1) , 'BACHELOR_OF_SCIENCE')
BACHELOR_OF_PHARMACY = ctrl.Consequent(np.arange(72,81,1) , 'BACHELOR_OF_PHARMACY')
BIOTECHNOLOGY = ctrl.Consequent(np.arange(85,91,1) , 'BIOTECHNOLOGY')
BACHELOR_OF_COMMERCE = ctrl.Consequent(np.arange(71,79,1) , 'BACHELOR_OF_COMMERCE')
BBA = ctrl.Consequent(np.arange(73,82,1) , 'BBA')
BMS = ctrl.Consequent(np.arange(73,78,1) , 'BMS')
GENERAL_BANKING = ctrl.Consequent(np.arange(65,78,1) , 'GENERAL_BANKING')
CHARTERED_ACCOUNTANCY = ctrl.Consequent(np.arange(77,81,1) , 'CHARTERED_ACCOUNTANCY')
COMPANY_SECRETARY = ctrl.Consequent(np.arange(78,82,1) , 'COMPANY_SECRETARY')
CERTIFIED_FINANCIAL_PLANNER = ctrl.Consequent(np.arange(70,82,1) , 'CERTIFIED_FINANCIAL_PLANNER')
BACHELOR_OF_ARTS = ctrl.Consequent(np.arange(65,76,1) , 'BACHELOR_OF_ARTS')
BACHELOR_OF_SOCIAL_WORK = ctrl.Consequent(np.arange(62,70,1) , 'BACHELOR_OF_SOCIAL_WORK')
BACHELOR_OF_FINE_ARTS = ctrl.Consequent(np.arange(60,74,1) , 'BACHELOR_OF_FINE_ARTS')
BACHELOR_OF_JOURNALISM = ctrl.Consequent(np.arange(63,72,1) , 'BACHELOR_OF_JOURNALISM')
BACHELOR_OF_LAWS = ctrl.Consequent(np.arange(65,76,1) , 'BACHELOR_OF_LAWS')
HOTEL_MANAGEMENT = ctrl.Consequent(np.arange(55,62,1) , 'HOTEL_MANAGEMENT')
BACHELOR_OF_FITNESS = ctrl.Consequent(np.arange(50,54,1) , 'BACHELOR_OF_FITNESS')
ANIMATION_AND_GRAPHICS = ctrl.Consequent(np.arange(45,52,1) , 'ANIMATION_AND_GRAPHICS')
PHOTOJOURNALISM = ctrl.Consequent(np.arange(40,46,1), 'PHOTOJOURNALISM')
BACHELOR_FISHERIES_SCIENCE = ctrl.Consequent(np.arange(35,42,1) , 'BACHELOR_FISHERIES_SCIENCE')
DIPLOMA_IN_RETAIL_MARKETING = ctrl.Consequent(np.arange(30,36,1) , 'DIPLOMA_IN_RETAIL_MARKETING')
BACHELOR_OF_PHYSIOTHERAPY = ctrl.Consequent(np.arange(25,32,1) , 'BACHELOR_OF_PHYSIOTHERAPY')
OF_OWN_CHOICE = ctrl.Consequent(np.arange(0,26,1) , 'OF_OWN_CHOICE')

# %%
# MEMBERSHIP FUNCTIONS >>>>>
#---------------------------------------------------------------
PHYSICS['poor'] = fuzzy.trimf(PHYSICS.universe , [0,25,31])
PHYSICS['average'] = fuzzy.trimf(PHYSICS.universe , [28,33,39])
PHYSICS['good'] = fuzzy.trapmf(PHYSICS.universe , [36,45,56,61])
PHYSICS['excellent'] = fuzzy.trimf(PHYSICS.universe , [58,67,100])

CHEMISTRY['poor'] = fuzzy.trimf(CHEMISTRY.universe , [0,25,31])
CHEMISTRY['average'] = fuzzy.trimf(CHEMISTRY.universe , [28,33,39])
CHEMISTRY['good'] = fuzzy.trapmf(CHEMISTRY.universe , [36,45,56,61])
CHEMISTRY['excellent'] = fuzzy.trimf(CHEMISTRY.universe , [58,67,100])
# CHEMISTRY.automf(7)
MATHS['poor'] = fuzzy.trimf(MATHS.universe , [0,25,31])
MATHS['average'] = fuzzy.trimf(MATHS.universe , [28,33,39])
MATHS['good'] = fuzzy.trapmf(MATHS.universe , [36,45,56,61])
MATHS['excellent'] = fuzzy.trimf(MATHS.universe , [58,67,100])

ENGLISH['poor'] = fuzzy.trimf(ENGLISH.universe , [0,25,31])
ENGLISH['average'] = fuzzy.trimf(ENGLISH.universe , [28,33,39])
ENGLISH['good'] = fuzzy.trapmf(ENGLISH.universe , [36,45,56,61])
ENGLISH['excellent'] = fuzzy.trimf(ENGLISH.universe , [58,67,100])

BIOLOGY['poor'] = fuzzy.trimf(BIOLOGY.universe , [0,25,31])
BIOLOGY['average'] = fuzzy.trimf(BIOLOGY.universe , [28,33,39])
BIOLOGY['good'] = fuzzy.trapmf(BIOLOGY.universe , [36,45,56,61])
BIOLOGY['excellent'] = fuzzy.trimf(BIOLOGY.universe , [58,67,100])

Computer_Science['poor'] = fuzzy.trimf(Computer_Science.universe , [0,25,31])
Computer_Science['average'] = fuzzy.trimf(Computer_Science.universe , [28,33,39])
Computer_Science['good'] = fuzzy.trapmf(Computer_Science.universe , [36,45,56,61])
Computer_Science['excellent'] = fuzzy.trimf(Computer_Science.universe , [58,67,100])

physical_education['poor'] = fuzzy.trimf(physical_education.universe , [0,25,31])
physical_education['average'] = fuzzy.trimf(physical_education.universe , [28,33,39])
physical_education['good'] = fuzzy.trapmf(physical_education.universe , [36,45,56,61])
physical_education['excellent'] = fuzzy.trimf(physical_education.universe , [58,67,100])

FINANCE['poor'] = fuzzy.trimf(FINANCE.universe , [0,25,31])
FINANCE['average'] = fuzzy.trimf(FINANCE.universe , [28,33,39])
FINANCE['good'] = fuzzy.trapmf(FINANCE.universe , [36,45,56,61])
FINANCE['excellent'] = fuzzy.trimf(FINANCE.universe , [58,67,100])

ACCOUNTANCY['poor'] = fuzzy.trimf(ACCOUNTANCY.universe , [0,25,31])
ACCOUNTANCY['average'] = fuzzy.trimf(ACCOUNTANCY.universe , [28,33,39])
ACCOUNTANCY['good'] = fuzzy.trapmf(ACCOUNTANCY.universe , [36,45,56,61])
ACCOUNTANCY['excellent'] = fuzzy.trimf(ACCOUNTANCY.universe , [58,67,100])

BUSINESS_STUDIES['poor'] = fuzzy.trimf(BUSINESS_STUDIES.universe , [0,25,31])
BUSINESS_STUDIES['average'] = fuzzy.trimf(BUSINESS_STUDIES.universe , [28,33,39])
BUSINESS_STUDIES['good'] = fuzzy.trapmf(BUSINESS_STUDIES.universe , [36,45,56,61])
BUSINESS_STUDIES['excellent'] = fuzzy.trimf(BUSINESS_STUDIES.universe , [58,67,100])

ECONOMICS['poor'] = fuzzy.trimf(ECONOMICS.universe , [0,25,31])
ECONOMICS['average'] = fuzzy.trimf(ECONOMICS.universe , [28,33,39])
ECONOMICS['good'] = fuzzy.trapmf(ECONOMICS.universe , [36,45,56,61])
ECONOMICS['excellent'] = fuzzy.trimf(ECONOMICS.universe , [58,67,100])

HISTORY['poor'] = fuzzy.trimf(HISTORY.universe , [0,25,31])
HISTORY['average'] = fuzzy.trimf(HISTORY.universe , [28,33,39])
HISTORY['good'] = fuzzy.trapmf(HISTORY.universe , [36,45,56,61])
HISTORY['excellent'] = fuzzy.trimf(HISTORY.universe , [58,67,100])

GEOGRAPHY['poor'] = fuzzy.trimf(GEOGRAPHY.universe , [0,25,31])
GEOGRAPHY['average'] = fuzzy.trimf(GEOGRAPHY.universe , [28,33,39])
GEOGRAPHY['good'] = fuzzy.trapmf(GEOGRAPHY.universe , [36,45,56,61])
GEOGRAPHY['excellent'] = fuzzy.trimf(GEOGRAPHY.universe , [58,67,100])

SOCIOLOGY['poor'] = fuzzy.trimf(SOCIOLOGY.universe , [0,25,31])
SOCIOLOGY['average'] = fuzzy.trimf(SOCIOLOGY.universe , [28,33,39])
SOCIOLOGY['good'] = fuzzy.trapmf(SOCIOLOGY.universe , [36,45,56,61])
SOCIOLOGY['excellent'] = fuzzy.trimf(SOCIOLOGY.universe , [58,67,100])

# %%
SOCIOLOGY.view()
GEOGRAPHY.view()
# Out:
# C:\Users\Intesab\Anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
''''''# OUTPUTS >>>>>
#------------------------------------------------------------------

ENGINEERING = ctrl.Consequent(np.arange(85,101,1) , 'ENGINEERING')
MBBS = ctrl.Consequent(np.arange(88,101,1) , 'MBBS')
BAMS = ctrl.Consequent(np.arange(80,90,1) , 'BAMS')
BHMS = ctrl.Consequent(np.arange(74,83,1) , 'BHMS')
BDS = ctrl.Consequent(np.arange(76,85,1) , 'BDS')
BACHELOR_OF_SCIENCE = ctrl.Consequent(np.arange(78,86,1) , 'BACHELOR_OF_SCIENCE')
BACHELOR_OF_PHARMACY = ctrl.Consequent(np.arange(72,81,1) , 'BACHELOR_OF_PHARMACY')
BIOTECHNOLOGY = ctrl.Consequent(np.arange(85,91,1) , 'BIOTECHNOLOGY')
BACHLEOR_OF_COMMERCE = ctrl.Consequent(np.arange(71,79,1) , 'BACHELOR_OF_COMMERCE')
BBA = ctrl.Consequent(np.arange(73,82,1) , 'BBA')
BMS = ctrl.Consequent(np.arange(73,78,1) , 'BMS')
GENERAL_BANKING = ctrl.Consequent(np.arange(65,78,1) , 'GENERAL_BANKING')
CHARTERED_ACCOUNTANCY = ctrl.Consequent(np.arange(77,81,1) , 'CHARTERED_ACCOUNTANCY')
COMPANY_SECRETARY = ctrl.Consequent(np.arange(78,82,1) , 'COMPANY_SECRETARY')
CERTIFIED_FINANCIAL_PLANNER = ctrl.Consequent(np.arange(70,82,1) , 'CERTIFIED_FINANCIAL_PLANNER')
BACHELOR_OF_ARTS = ctrl.Consequent(np.arange(65,76,1) , 'BACHELOR_OF_ARTS')
BACHELOR_OF_SOCIAL_WORK = ctrl.Consequent(np.arange(62,70,1) , 'BACHELOR_OF_SOCIAL_WORK')
BACHELOR_OF_FINE_ARTS = ctrl.Consequent(np.arange(60,74,1) , 'BACHELOR_OF_FINE_ARTS')
BACHELOR_OF_JOURNALISM = ctrl.Consequent(np.arange(63,72,1) , 'BACHELOR_OF_JOURNALISM')
BACHELOR_OF_LAWS = ctrl.Consequent(np.arange(65,76,1) , 'BACHELOR_OF_LAWS')
HOTEL_MANAGEMENT = ctrl.Consequent(np.arange(55,62,1) , 'HOTEL_MANAGEMENT')
BACHELOR_OF_FITNESS = ctrl.Consequent(np.arange(50,54,1) , 'BACHELOR_OF_FITNESS')
ANIMATION_AND_GRAPHICS = ctrl.Consequent(np.arange(45,52,1) , 'ANIMATION_AND_GRAPHICS')
PHOTOJOURNALISM = ctrl.Consequent(np.arange(40,46,1), 'PHOTOJOURNALISM')
BACHELOR_FISHERIES_SCIENCE = ctrl.Consequent(np.arange(35,42,1) , 'BACHELOR_FISHERIES_SCIENCE')
DIPLOMA_IN_RETAIL_MARKETING = ctrl.Consequent(np.arange(30,36,1) , 'DIPLOMA_IN_RETAIL_MARKETING')
BACHELOR_OF_PHYSIOTHERAPY = ctrl.Consequent(np.arange(25,32,1) , 'BACHELOR_OF_PHYSIOTHERAPY')
OF_OWN_CHOICE = ctrl.Consequent(np.arange(0,26,1) , 'OF_OWN_CHOICE')


# MEMBERSHIP FUNCTION FOR DIFFERENT CONSEQUENTS ...>>>>
#--------------------------------------------------------------------------------------------

ENGINEERING['CIVIL'] = fuzzy.trimf(ENGINEERING.universe , [85,88,90])
ENGINEERING['MECHANICAL'] = fuzzy.trimf(ENGINEERING.universe , [87,91,93])
ENGINEERING['ELECTRICAL'] = fuzzy.trapmf(ENGINEERING.universe , [90,92,94,96])
ENGINEERING['CSE'] = fuzzy.trimf(ENGINEERING.universe , [95,97,100])

MBBS['GYNAECOLOGY'] = fuzzy.trimf(MBBS.universe , [89,90,92])
MBBS['OBSTETRICS'] = fuzzy.trimf(MBBS.universe , [91,94,96])
MBBS['RADIODIAGNOSIS'] = fuzzy.trapmf(MBBS.universe , [92,93,95,97])
MBBS['GENERAL_MEDICINE'] = fuzzy.trimf(MBBS.universe , [94,98,100])

#  80,90,1
BAMS['low_scale'] = fuzzy.trimf(BAMS.universe , [80,82,84])
BAMS['average_scale'] = fuzzy.trimf(BAMS.universe , [81,83,87])
BAMS['good_scale'] = fuzzy.trimf(BAMS.universe , [82,85,86])
BAMS['excellent_scale'] = fuzzy.trimf(BAMS.universe , [83,87,90])

# FINANCE['low_scale'] = fuzzy.trimf(FINANCE.universe , [80,82,84])
# FINANCE['average_scale'] = fuzzy.trimf(FINANCE.universe , [81,83,87])
# FINANCE['good_scale'] = fuzzy.trimf(FINANCE.universe , [82,85,86])
# FINANCE['excellent_scale'] = fuzzy.trimf(FINANCE.universe , [83,87,90])

# %%
# rule1 = ctrl.Rule(physics['poor'] & chemistry['poor'] & maths['poor'] & english['poor'] & biology['poor'] & Computer_Science['poor'] & physical_education['poor'] & finance['poor'] | Accounts['poor'] & Business['poor'] & Economics['poor'] & history['poor'] & geography['poor'] & sociology['poor'] , engineering['civil'])
rule1 = ctrl.Rule(PHYSICS['poor'] | CHEMISTRY['poor'] & MATHS['average'] & ENGLISH['average'] & Computer_Science['poor'] & BIOLOGY['poor'] , ENGINEERING['CIVIL'])
rule2 = ctrl.Rule(PHYSICS['good'] & CHEMISTRY['poor'] & MATHS['good'] | ENGLISH['average'] & Computer_Science['good'] & BIOLOGY['poor'] , ENGINEERING['CSE'])
rule3 = ctrl.Rule(PHYSICS['good'] & CHEMISTRY['poor'] | MATHS['average'] | ENGLISH['average'] & Computer_Science['average'] & BIOLOGY['poor'] , ENGINEERING['ELECTRICAL'])

# %%
tipping_cntrl = ctrl.ControlSystem([rule1,rule2,rule3])
tipping = ctrl.ControlSystemSimulation(tipping_cntrl)
tipping.input['PHYSICS'] = 60
tipping.input['CHEMISTRY'] = 30
tipping.input['MATHS'] = 60
tipping.input['ENGLISH'] = 70
tipping.input['BIOLOGY'] = 56
000.tipping.input['Computer_Science'] = 58
# tipping.input['']
# tipping.input['FINANCE'] = 46 
#-------------------------------------------------------------------------------------------
tipping.compute()
print (tipping.output['ENGINEERING'])
ENGINEERING.view(sim=tipping)
# Out:
# 94.95893719806762

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skfuzzy as fuzzy
from skfuzzy import control as ctrl


physics = ctrl.Antecedent(np.arange(0,101,1) , 'PHYSICS')
chemistry = ctrl.Antecedent(np.arange(0,101,1) , 'CHEMISTRY')
engineering = ctrl.Consequent(np.arange(0,35,1) , 'ENGINEERING')

# %%
physics['poor'] = fuzzy.trimf(physics.universe , [0,25,31])
physics['average'] = fuzzy.trimf(physics.universe , [28,33,39])
physics['good'] = fuzzy.trapmf(physics.universe , [36,45,56,61])
physics['excellent'] = fuzzy.trimf(physics.universe , [58,67,100])

chemistry['poor'] = fuzzy.trimf(chemistry.universe , [10,18,25])
chemistry['average'] = fuzzy.trimf(chemistry.universe , [15,29,33])
chemistry['good'] = fuzzy.trapmf(chemistry.universe , [25,38,52,60])
chemistry['excellent'] = fuzzy.trimf(chemistry.universe , [58,67,100])

# %%
engineering['poor'] = fuzzy.trimf(engineering.universe , [0,30,40])
engineering['average'] = fuzzy.trimf(engineering.universe , [25,38,45])
engineering['good'] = fuzzy.trimf(engineering.universe , [40,44,100])
